# %% [markdown]
# # TP2 Interpolation Numérique
# <img src="tp2an.png">

# %% [markdown]
# ## Exercice 1

# %% [markdown]
# On considère le programme MATLAB suivant :
# ``` octave
# function u=prog(x,y,c)
# S = y;
# n = length(x);
# for j=1:n
#     L = c-x;
#     for k=1:n
#         if (k == j)
#            L(k) = 1;
#         else
#            L(k) = L(k)/(x(j) - x(k));
#         end
#     end
#     S(j) = S(j)*prod(L);
# end
# u=sum(S);
# ```

# %% [markdown]
# ## Version Python

# %%
from numpy import prod
def prog(x,y,c):
    S = [] 
    n = len(x)
    
    for j in range(n):
        L =[c-xx for xx in x]
        for k in range(n):
            if (k == j):                
                L[k] = 1
            else:
                L[k] = L[k]/(x[j] - x[k])   
        S.append(y[j]*prod(L))
        
    return  sum(S)

# %%
X=[1 ,2 ,3 ,4,-2];
Y=[-1, 0, 2 ,1,3];
for i in X:
    print(prog(X,Y,i))
sum(X)
# Out:
# -1.0
# 0.0
# 2.0
# 1.0
# 3.0
# 8

# %% [markdown]
# **Polynome d'interpolation de Lagrange**
# > Soient $(x_0,y_0), \ldots,(x_k,y_k),\ldots ,(x_n,k_n)$ $n+1$ points deux à deux distincts, le polynôme d'interpolation de Lagrange associés à ces points supports est défini par :
# > $$P_n(x)=\sum_{k=0}^{n-1} y_kL_k(x)$$
#
# avec $L_{0}(x)=\displaystyle\frac{(x-x_1)(x-x_2)\ldots(x-x_{n})}{(x_0-x_1)(x_0-x_2)\ldots(x_0-x_{n})}$ et $L_{k}(x)=\displaystyle\frac{(x-x_1)(x-x_2)\ldots(x-x_{k-1})(x-x_{k+1})\ldots(x_0-x_{n})}{(x_k-x_0)(x_k-x_1)\ldots(x_k-x_{k-1})(x_k-x_{k+1})\ldots(x_k-x_{n})}$ pour $k\in \{1,\ldots,n\}$

# %% [markdown]
# 1) Que renvoie la fonction PR lorsqu'on lui déclare  **x=(x(1),x(2),...,x(n))x=(x(1),x(2),...,x(n))**  et  **y=(y(1),y(2),...,y(n))y=(y(1),y(2),...,y(n))**  deux vecteurs de même longueur  `n` et `c`  un nombre réel donné.

# %%
def PR(x,y,c):
    S = []
    n = len(x)
    for j in range(1,n):
        L=[c-xx for xx in x]
        for k in range(n):
            if (k == j):                
                L[k] = 1
            else:
                L[k] = L[k]/(x[j] - x[k])   
        S.append(y[j]*prod(L))
    return sum(S)

# %%
X=[1,2,3,4];
Y=[-1,0,2,1];
for i in X :
    print("u= ",PR(X,Y,i))
# Out:
# u=  0.0
# u=  0.0
# u=  2.0
# u=  1.0

# %% [markdown]
# 2) Que contient le vecteur  LL  après la fin de la boucle  kk .

# %%
x=[1,2,3,4];
y=[-1,0,2,1];

# %%
S = y
n = len(x)
for c in X :
    for j in range (1,n):
        L=[c-xx for xx in x]
        for k in range(n):
            if (k == j):                
                L[k] = 1
            else:
                L[k] = L[k]/(x[j] - x[k])   
sum (S)
# Out:
# 2

# %%
L
# Out:
# [1.0, 1.0, 1.0, 1]

# %% [markdown]
# 3) Utiliser cette fonction pour dessiner le graph du polynôme de Lagrange  de la fonction $f(x) = \dfrac{1}{1 + x^2}$ aux points $x=[-1:0.1:1]$.

# %%
import numpy as np
import matplotlib.pyplot as plt 
x=np.arange(-1,1,0.1)
f= lambda x : 1/(1+ x**2)
y=f(x)
pt=[]
t=np.linspace(-1,1,100)
for u in range(len(t)):
    pt.append(PR(x,y,t[u]))
plt.plot(t,pt,'r',label='pt')
plt.plot(x,y,'bo',label='y')
plt.plot(t,f(t),'g',label='f(t)')
plt.title('polynôme de Lagrange de f ')
plt.legend()
plt.show()

# %% [markdown]
# 4) On considère la fonction $F$ suivante :
# $$
# F(h) = \pi -\cos \left(\frac{h}{2}\right) + h \sqrt{1-\left(\frac{h}{2}\right)^2}, \qquad
# h\in [0,2],
# $$
# et les points d'interpolation $x_i = ih$, $0\leq i\leq n$, avec $ n=20$ et $h=0.1$.

# %% [markdown]
# 4.1) Représenter sur un même graphe la fonction $F$ et $p_n$, où
#  $p_n$ est le polynôme d'interpolation de Lagrange de $F$ aux
#  points $x_0,\,\ldots,\,x_n$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import *
x=np.arange(0,3)
f= lambda x:pi-cos(x/2)+x*sqrt(1-(x/2)**2)
f2=np.vectorize(f)
y=f2(x)
pn=[]
t=np.linspace(0,2,20)
for i in range (len(t)):
    pn.append(PR(x,y,t[i])) 
plt.plot(t,pn,'r',label='Pn')
plt.plot(x,y,'bo',label='y')
plt.plot(t,f2(t),'g',label='f(t)')
plt.legend()
plt.show()

# %% [markdown]
# 2)Tracer la courbe d'erreur  (la
#  fonction $F-p_n$). Qu'observer vous.

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import *
x=np.arange(0,3)
f= lambda x:pi-cos(x/2)+x*sqrt(1-(x/2)**2)
f2=np.vectorize(f)
y=f2(x)
pn=[]
t=np.linspace(0,2,20)
for u in range(len(t)):
    pn.append(PR(x,y,t[u]))
plt.plot(t,f2(t)-pn,'r',label='F-pn')
plt.title(' F - Pn ')
plt.legend()
plt.show()

# %% [markdown]
# ## Exercice 2  ( Phenomène de Runge )

# %% [markdown]
# 1) Vérifier que sur $[-5,5]$ le polynôme d'interpolation de Lagrange
#   de la fonction $f$ définie par $f(x)=\displaystyle{\frac{1}{1+x^2}}$,
# en $N$ points uniformément espacés ne convergent pas correctement aux voisinages de $-1$ et $1$, pour $N=7,8,9,10 ...$

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(3,figsize=(8,8))
plt.gcf().subplots_adjust(left = 0.2, bottom = 0.2, right = 1.5,
                          top = 0.9, wspace = 0.2, hspace = 0.3)
N=7
X=np.linspace(-5,5,N)
plt.suptitle("Interpolation Equidistante ",size="x-large" )
f=lambda x:1/(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title(" avec N=7")
##############################
N=8
X=np.linspace(-5,5,N)
f=lambda x: 1/(1+x**2)
Y=f(X);
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title(" avec N=8")
##############################
N=9
X=np.linspace(-5,5,N)
f=lambda x: 1/(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("avec N=9")
##############################
N=10
X=np.linspace(-5,5,N)
f=lambda x: 1/(1+x**2)
Y=f(X);
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title(" avec N=10")
# Out:
# Text(0.5, 1.0, ' avec N=10')

# %% [markdown]
# 2) Les points de Tchebycheff sur un intervalle $[a;b]$ sont définie par :
#   $$x_k=\dfrac{a+b}{2}+\dfrac{a-b}{2}\cos\left(\frac{k-1}{n-1}\pi\right)\hspace{0.5cm} (k=1,..,n: x_1=a:x_n=b)$$
#
#   Vérifier que sur $[-5; 5]$ ; l'interpolation polynômiale de $f(x) = \dfrac{1}{1 + x^2}$ ; en $N$ points de Tchebychev
# est meilleure qu'une  interpolation utilisant $N$ points uniforment espacés (on prendra $N=10, 11, 16, 17$).

# %%
from math import *
def tcheb(a,b,n):
    V=[]
    for k in range(n):
        V.append((a+b)/2+((a-b)/2)*cos(((k-1)/(n-1))*pi))
      
    return V
tcheb(-5,5,11)
# Out:
# [-4.755282581475767,
#  -5.0,
#  -4.755282581475767,
#  -4.045084971874737,
#  -2.938926261462366,
#  -1.5450849718747373,
#  -3.061616997868383e-16,
#  1.5450849718747368,
#  2.938926261462365,
#  4.045084971874736,
#  4.755282581475767]

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(3,figsize=(8,8))
plt.gcf().subplots_adjust(left = 0.2, bottom = 0.2, right = 1.5,
                          top = 0.9, wspace = 0.2, hspace = 0.3)
plt.suptitle("Interpolation Tchebycheff ",size="x-large" )
Yt=[]
N=10
f=lambda x: 1/(1+x**2)
Xt=tcheb(-5,5,N)
for i in Xt:
    Yt.append(f(i))
pt=np.polyfit(Xt,Yt,N-1)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r',Xt,Yt,'ob', t, np.polyval(pt,t),'g')
plt.title("avec N=10")
##########################################
Yt=[]
N=11
f=lambda x: 1/(1+x**2)
Xt=tcheb(-5,5,N)
for i in Xt:
    Yt.append(f(i))
pt=np.polyfit(Xt,Yt,N-1)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r',Xt,Yt,'ob', t, np.polyval(pt,t),'g')
plt.title(" avec N=11")
##########################################
Yt=[]
N=16
f=lambda x: 1/(1+x**2)
Xt=tcheb(-5,5,N)
for i in Xt:
    Yt.append(f(i))
pt=np.polyfit(Xt,Yt,N-1)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r',Xt,Yt,'ob', t, np.polyval(pt,t),'g')
plt.title(" avec N=16")
##########################################
Yt=[]
N=17
f=lambda x: 1/(1+x**2)
Xt=tcheb(-5,5,N)
for i in Xt:
    Yt.append(f(i))
pt=np.polyfit(Xt,Yt,N-1)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r',Xt,Yt,'ob', t, np.polyval(pt,t),'g')
plt.title("avec N=17")
# Out:
# C:\Users\MPI\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\MPI\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\MPI\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\MPI\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'avec N=17')

# %% [markdown]
# ## Exercice 3

# %% [markdown]
# On considère les deux programme MATLAB suivant :
# ``` octave
# function f=intN(x,f)% RECURSIVE
# m=length(x);
# for k=2:m;
#     f(k:m)=(f(k:m)-f(k-1:m-1))./(x(k:m)-x(1:m+1-k))
# end
# ```
# ``` octave
# function p=intNval(x,c,t)
# m=length(x);
# p=c(m)*ones(size(t));
# for k=m-1:-1:1;
#     p=p.*(t-x(k))+c(k);
# end
# ```

# %% [markdown]
# 1) Déterminer en utilisant les deux codes puis par un calcul à la main le polynôme de Newton pour les données suivantes :
#
#
# <center>
# <table>
#       $\begin{array}{|c|c|c|}
#    \hline
#    i & x_i  & y_i \\
#    \hline
#    0 &   -1  &   6 \\
#    1 &   0 &  1 \\
#    2 &  2  &  3 \\
#    3 &  5  &  66 \\
#    \hline
# \end{array}$
# </table>
# </center>

# %%
import numpy as np 
def intN(x,y):
    m=len(x)
    y=np.array(y)
    x=np.array(x)
    for k in range(2,m):
        y[k:m]=(y[k:m]-y[k-1:m-1])/(x[k:m]-x[1:m+1-k])
    return y

# %%
x=[-1,0,2,5]
y=[6,1,3,66]
f=intN(x,y)
print(f)
# Out:
# [6 1 1 4]

# %%
def intNval(x,y,t):
    m=len(x)
    x= np.array(x)
    y=np.array(y)
    p=y[m-1]*np.ones(np.size(t))
    for k in np.arange(m-1,1,-1):
        p=p*(t-x[k])+y[k]
    return p

# %%
x=[-1,0,2,5]
y=[6,1,3,66]
t=[0,1,2,3]
f=intNval(x,y,t)
print(f)
# Out:
# [531. 201.   3. -63.]

# %% [markdown]
# 2) Donner le Graph du polynôme trouvé en 1) dans l'intervalle $[-1;5]$.

# %%
import matplotlib.pyplot as plt
x=[-1,0,2,5];
y=[6,1,3,66];
f=intN(x,y);
plt.plot(x,f,'r',x,y,'ob')
# Out:
# [<matplotlib.lines.Line2D at 0x21c8009a6d0>,
#  <matplotlib.lines.Line2D at 0x21c8009a790>]

# %% [markdown]
# 3) Calculer $P(1)$ en utilisant le polynôme trouvé en 1).

# %%
x=[-1,0,2,5]
y=[6,1,3,66]
t=[0,1,2,3]
p=intNval(x,y,t)
p[1]
# Out:
# 201.0
